# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:\\Users\\pc\\Desktop\\jupyter_notebook\\breast cancer.csv',index_col=0)

# %%
df.head()
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  texture_worst  \
# id                                            ...
# ...

# %%
df.head()
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  texture_worst  \
# id                                            ...
# ...

# %%
df.shape
# Out:
# (569, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 569 entries, 842302 to 92751
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
df = df.drop(['Unnamed: 32'],axis=1)

# %%
df.head()
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  radius_worst  \
# id                                            ...
# ...

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
#no null column it so safe continue proceed

# %%
df.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
print('beligin tomur',df.diagnosis.value_counts()[0])
print('melignant tomur',df.diagnosis.value_counts()[1])
# Out:
# beligin tomur 357
# melignant tomur 212

# %%
#dataset is no imbalanced so we are good to proceed

# %%
sns.countplot(x='diagnosis',data=df)
plt.show()

# %%
df.shape
# Out:
# (569, 31)

# %% [markdown]
# # using select kbest feature selection method

# %%
#select kbest use f_claasif to find best feature where f_classif use annova test

# %%
from sklearn.feature_selection import SelectKBest,f_classif

# %%
#replace labels column digonosis into binary codes
df['diagnosis'] = df['diagnosis'].replace({'M':1,'B':0})

# %%
df
# Out:
#           diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302            1        17.99         10.38          122.80     1001.0
# 842517            1        20.57         17.77          132.90     1326.0
# 84300903          1        19.69         21.25          130.00     1203.0
# 84348301          1        11.42         20.38           77.58      386.1
# 84358402          1        20.29         14.34          135.10     1297.0
# ...             ...          ...           ...             ...        ...
# 926424            1        21.56         22.39          142.00     1479.0
# 926682            1        20.13         28.25          131.20     1261.0
# 926954            1        16.60         28.08          108.30      858.1
# 927241            1        20.60         29.33          140.10     1265.0
# 92751             0         7.76         24.54           47.92      181.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# ...

# %%
x = df.drop('diagnosis',axis=1)
y=df.diagnosis

# %%
best_features = SelectKBest(score_func=f_classif,k=17)
fit = best_features.fit(x,y)
df_scores = pd.DataFrame(fit.scores_)
df_columns = pd.DataFrame(df.columns)


#concatenate dataframe

# %%
features_scores = pd.concat([df_scores,df_columns],axis=1)
features_scores.columns = ['feature_Name','score']#put the column nme

# %%
print(features_scores.nlargest(17,'score'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5612/42656958.py in <module>
# ----> 1 print(features_scores.nlargest(17,'score'))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in nlargest(self, n, columns, keep)
#    6634         Brunei      434000    12128      BN
#    6635         """
# -> 6636         return algorithms.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#    6637
#    6638     def nsmallest(self, n, columns, keep: str = "first") -> DataFrame:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py in nlargest(self)
#    1219     @final
#    1220     def nlargest(self):
# -> 1221         return self.compute("nlargest")
#    1222
#    1223     @final
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py in compute(self, method)
# ...
